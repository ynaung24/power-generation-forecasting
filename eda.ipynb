# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('train.csv', parse_dates=['Datetime'], index_col='Datetime')
df
# Out:
#                            ActivePower  AmbientTemperatue  \
# Datetime
# 2018-01-01 06:20:00+00:00    26.212347          28.696304
# 2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2018-01-01 06:50:00+00:00    40.889650          28.984758
# 2018-01-01 10:40:00+00:00    34.398111          30.282058
# 2018-01-01 12:00:00+00:00    29.797653          29.333519
# ...                                ...                ...
# 2020-03-15 23:10:00+00:00   272.852287          23.500851
# 2020-03-15 23:20:00+00:00   295.675931          23.409183
# 2020-03-15 23:30:00+00:00   295.127333          23.336964
# 2020-03-15 23:40:00+00:00   342.942216          23.310323
# 2020-03-15 23:50:00+00:00   374.401860          23.297918
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# Datetime
# 2018-01-01 06:20:00+00:00                      NaN               NaN
# 2018-01-01 06:40:00+00:00                      NaN               NaN
# ...

# %%
df['TurbineStatus'].value_counts()

# %%
df['TurbineStatus'].isna().sum()
# Out:
# 26466

# %%
df.describe()
# Out:
#         ActivePower  AmbientTemperatue  BearingShaftTemperature  \
# count  77202.000000       76306.000000             50518.000000
# mean     744.836678          28.393400                43.804575
# std      597.080992           4.111239                 5.005754
# min        0.000000           0.000000                 0.000000
# 25%      225.710444          25.430483                40.492248
# 50%      556.135900          27.999622                43.738314
# 75%     1279.882107          31.166240                47.769240
# max     1779.032433          41.809714                55.088655
#
#        Blade1PitchAngle  Blade2PitchAngle  Blade3PitchAngle  \
# count      33920.000000      33837.000000      33837.000000
# mean           3.099613          3.560774          3.560774
# std           11.186776         11.088078         11.088078
# min           -1.960466         -2.406213         -2.406213
# 25%           -0.980198         -0.470198         -0.470198
# ...

# %%
df.isna().sum()
# Out:
# ActivePower                         0
# AmbientTemperatue                 896
# BearingShaftTemperature         26684
# Blade1PitchAngle                43282
# Blade2PitchAngle                43365
# Blade3PitchAngle                43365
# GearboxBearingTemperature       26682
# GearboxOilTemperature           26670
# GeneratorRPM                    26674
# GeneratorWinding1Temperature    26656
# GeneratorWinding2Temperature    26649
# HubTemperature                  26792
# MainBoxTemperature              26704
# NacellePosition                 20424
# ReactivePower                      42
# RotorRPM                        26680
# TurbineStatus                       0
# WindDirection                   20424
# WindSpeed                         308
# dtype: int64

# %%
missing_per_row = df.isnull().sum(axis=1) / len(df.columns)
print("Rows with more than 50% missing values:", sum(missing_per_row > 0.5))

valid_ranges = {
    'ActivePower': (min(df['ActivePower']), max(df['ActivePower'])),
    'AmbientTemperatue': (min(df['AmbientTemperatue']), max(df['AmbientTemperatue'])),
    'BearingShaftTemperature': (min(df['BearingShaftTemperature']), max(df['BearingShaftTemperature'])),
    'Blade1PitchAngle': (min(df['Blade1PitchAngle']), max(df['Blade1PitchAngle'])),
    'Blade2PitchAngle': (min(df['Blade2PitchAngle']), max(df['Blade2PitchAngle'])),
    'Blade3PitchAngle': (min(df['Blade3PitchAngle']), max(df['Blade3PitchAngle'])),
    'GearboxBearingTemperature': (min(df['GearboxBearingTemperature']), max(df['GearboxBearingTemperature'])),
    'GearboxOilTemperature': (min(df['GearboxOilTemperature']), max(df['GearboxOilTemperature'])),
    'GeneratorRPM': (min(df['GeneratorRPM']), max(df['GeneratorRPM'])),
    'GeneratorWinding1Temperature': (min(df['GeneratorWinding1Temperature']), max(df['GeneratorWinding1Temperature'])),
    'GeneratorWinding2Temperature': (min(df['GeneratorWinding2Temperature']), max(df['GeneratorWinding2Temperature'])),
    'HubTemperature': (min(df['HubTemperature']), max(df['HubTemperature'])),
    'MainBoxTemperature': (min(df['MainBoxTemperature']), max(df['MainBoxTemperature'])),
    'NacellePosition': (min(df['NacellePosition']), max(df['NacellePosition'])),
    'ReactivePower': (min(df['ReactivePower']), max(df['ReactivePower'])),
    'RotorRPM': (min(df['RotorRPM']), max(df['RotorRPM'])),
    'TurbineStatus': (min(df['TurbineStatus']), max(df['TurbineStatus'])),
    'WindDirection': (min(df['WindDirection']), max(df['WindDirection'])),
    'WindSpeed': (min(df['WindSpeed']), max(df['WindSpeed']))
}

columns_to_impute = df.columns[df.isnull().any()].tolist()

mice_imputer = IterativeImputer(
    estimator=RandomForestRegressor(
        n_estimators=100,
        max_depth=15,
        min_samples_leaf=5,
        n_jobs=-1
    ),
    initial_strategy='mean',
    n_nearest_features=10,
    random_state=42,
    max_iter=10,
    verbose=1
)

df_imputed = df.copy()
df_imputed.loc[:, columns_to_impute] = mice_imputer.fit_transform(df[columns_to_impute])

for column in columns_to_impute:
    missing_mask = df[column].isnull()
    if missing_mask.any():
        std = df[column].std()
        noise = np.random.normal(0, 0.001 * std, size=sum(missing_mask))
        df_imputed.loc[missing_mask, column] += noise
        
        if column in valid_ranges:
            min_val, max_val = valid_ranges[column]
            df_imputed[column] = df_imputed[column].clip(min_val, max_val)

print("\nOriginal DataFrame null counts:")
print(df.isnull().sum().sum())
print("\nImputed DataFrame null counts:")
print(df_imputed.isnull().sum().sum())

print("\nAfter imputation and constraints, value ranges:")
for column in df_imputed.columns:
    print(f"\n{column}:")
    print(f"Min: {df_imputed[column].min():.2f}")
    print(f"Max: {df_imputed[column].max():.2f}")

for column in df_imputed.columns:
    if df[column].isnull().any():
        n_unique = len(df_imputed[column][df[column].isnull()].unique())
        print(f"\nUnique imputed values in {column}: {n_unique}")
# Out:
# Rows with more than 50% missing values: 26647
# [IterativeImputer] Completing matrix with shape (77202, 17)
# [IterativeImputer] Change: 1247.299701267646, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 887.0107015435146, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 516.678021479533, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 332.36663605448643, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 182.09713236744915, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 179.91064937865562, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 90.90654399511644, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 200.1087654076797, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 254.50268917508777, scaled tolerance: 1.8099417000000002
# [IterativeImputer] Change: 301.8640392768817, scaled tolerance: 1.8099417000000002
#
# Original DataFrame null counts:
# ...

# %%
df_imputed
# Out:
#                            ActivePower  AmbientTemperatue  \
# Datetime
# 2018-01-01 06:20:00+00:00    26.212347          28.696304
# 2018-01-01 06:40:00+00:00    59.632658          29.052567
# 2018-01-01 06:50:00+00:00    40.889650          28.984758
# 2018-01-01 10:40:00+00:00    34.398111          30.282058
# 2018-01-01 12:00:00+00:00    29.797653          29.333519
# ...                                ...                ...
# 2020-03-15 23:10:00+00:00   272.852287          23.500851
# 2020-03-15 23:20:00+00:00   295.675931          23.409183
# 2020-03-15 23:30:00+00:00   295.127333          23.336964
# 2020-03-15 23:40:00+00:00   342.942216          23.310323
# 2020-03-15 23:50:00+00:00   374.401860          23.297918
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# Datetime
# 2018-01-01 06:20:00+00:00                45.618517         -0.965618
# 2018-01-01 06:40:00+00:00                45.595080         -0.965893
# ...

# %%
df_imputed.isna().sum().sum()
# Out:
# 0

# %%
df_imputed.to_csv('train_imputed.csv', index=True)
